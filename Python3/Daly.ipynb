# %%
import os
import pandas as pd

# %%
os.chdir("C:\\Users\\dpaul7\\VideoArchives")

# %%
os.listdir()
# Out:
# ['250A.asf',
#  '250B.asf',
#  '250C.asf',
#  '250D.asf',
#  '250E.asf',
#  '250F.asf',
#  '250G.asf',
#  '250H.asf',
#  '250J.asf',
#  '250K.asf',
#  '250L.asf',
#  '250M.asf',
#  'Augostini Anna PHM515 CS3 11-21-2017 - annaaugo.mp4',
#  'Avlasevich Viktoriya PHM515 CS3 11-21-2017 - vavlasev.mp4',
#  'Bhasin Nicholas PHM515 CS3 11-21-2017 - nbhasin2.mp4',
#  'Bienko Kevin PHM515 CS3 11-21-2017 - kevinbie.mp4',
#  'Blas Myles PHM515 CS3 11-21-2017 - mylesbla.mp4',
#  'Brighton Christopher PHM515 CS3 11-21-2017 - cabright.mp4',
#  'Butler Matthew PHM515 CS3 11-21-2017 - mbutler6.mp4',
#  'Butler McKenna PHM515 CS3 11-21-2017 - mbutler5.mp4',
#  'Cai Dennis PHM515 CS3 11-21-2017 - dcai2.mp4',
#  'Canales Gisela PHM515 CS3 11-21-2017 - giselaca.mp4',
#  'Cashman Nicholas PHM515 CS3 11-21-2017 - ncashman.mp4',
#  'Chan Garry PHM515 CS3 11-21-2017 - garrycha.mp4',
#  'Chen Jack PHM515 CS3 11-21-2017 - jchen222.mp4',
#  'Chen Kong Yu PHM515 CS3 11-21-2017 - kongyuch.mp4',
# ...

# %%
ren=pd.read_excel("rename.xlsx")

# %%
ren
# Out:
#                                             old  \
# 0          Augostini Anna PHM515 CS1 10-03-2017
# 1         Bhasin Nicholas PHM515 CS1 10-03-2017
# 2            Bienko Kevin PHM515 CS1 10-03-2017
# 3              Blas Myles PHM515 CS1 10-03-2017
# 4          Butler Matthew PHM515 CS1 10-03-2017
# 5          Butler McKenna PHM515 CS1 10-03-2017
# 6              Cai Dennis PHM515 CS1 10-03-2017
# 7        Cashman Nicholas PHM515 CS1 10-03-2017
# 8              Chan Garry PHM515 CS1 10-03-2017
# 9               Chen Jack PHM515 CS1 10-03-2017
# 10               Chen Lan PHM515 CS1 10-03-2017
# 11            Chen Zhilei PHM515 CS1 10-03-2017
# 12             Coiro Mark PHM515 CS1 10-03-2017
# 13        Danilov Michael PHM515 CS1 10-03-2017
# 14         Deinhart Lydia PHM515 CS1 10-03-2017
# 15      Dhaliwall Rajveer PHM515 CS1 10-03-2017
# 16             Fan Chiwai PHM515 CS1 10-03-2017
# 17      Fitzgibbon Dennis PHM515 CS1 10-03-2017
# ...

# %%
ren['old'].iloc[65]
# Out:
# 'Zheng Xinyue PHM515 CS1 10-03-2017'

# %%
range(len(os.listdir()))
# Out:
# range(0, 9)

# %%
os.listdir()[60][:-4]==ren['old'].iloc[60]
# Out:
# True

# %%
for i in range(len(os.listdir())):
    if(os.listdir()[i][:-4]==ren['old'].iloc[i]):
        os.rename(os.listdir()[i],ren['new'].iloc[i]+".asf")

# %%
os.listdir()
# Out:
# ['250A.asf',
#  '250B.asf',
#  '250C.asf',
#  '250D.asf',
#  '250E.asf',
#  '250F.asf',
#  '250G.asf',
#  '250H.asf',
#  '250J.asf',
#  '250K.asf',
#  '250L.asf',
#  '250M.asf',
#  'Augostini Anna PHM515 CS3 11-21-2017 - annaaugo.mp4',
#  'Avlasevich Viktoriya PHM515 CS3 11-21-2017 - vavlasev.mp4',
#  'Bhasin Nicholas PHM515 CS3 11-21-2017 - nbhasin2.mp4',
#  'Bienko Kevin PHM515 CS3 11-21-2017 - kevinbie.mp4',
#  'Blas Myles PHM515 CS3 11-21-2017 - mylesbla.mp4',
#  'Brighton Christopher PHM515 CS3 11-21-2017 - cabright.mp4',
#  'Butler Matthew PHM515 CS3 11-21-2017 - mbutler6.mp4',
#  'Butler McKenna PHM515 CS3 11-21-2017 - mbutler5.mp4',
#  'Cai Dennis PHM515 CS3 11-21-2017 - dcai2.mp4',
#  'Canales Gisela PHM515 CS3 11-21-2017 - giselaca.mp4',
#  'Cashman Nicholas PHM515 CS3 11-21-2017 - ncashman.mp4',
#  'Chan Garry PHM515 CS3 11-21-2017 - garrycha.mp4',
#  'Chen Jack PHM515 CS3 11-21-2017 - jchen222.mp4',
#  'Chen Kong Yu PHM515 CS3 11-21-2017 - kongyuch.mp4',
# ...

# %%
import os
import shutil

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dpaul7\\VideoArchives'

# %%
os.chdir("C:\\Users\\dpaul7\\VideoArchives")

# %%
len(os.listdir())
# Out:
# 142

# %%
for i in os.listdir():
    if(".mp4" in i):
        print("V:\\Students\\"+str(i[i.index(" - ")+3:-4])+"\t"+i)
        shutil.copy(src=i,dst="V:\\Students\\"+str(i[i.index(" - ")+3:-4]))
#         os.rename(i,i.replace("_%T1",""))
# Out:
# V:\Students\annaaugo	Augostini Anna PHM515 CS3 11-21-2017 - annaaugo.mp4
# V:\Students\vavlasev	Avlasevich Viktoriya PHM515 CS3 11-21-2017 - vavlasev.mp4
# V:\Students\nbhasin2	Bhasin Nicholas PHM515 CS3 11-21-2017 - nbhasin2.mp4
# V:\Students\kevinbie	Bienko Kevin PHM515 CS3 11-21-2017 - kevinbie.mp4
# V:\Students\mylesbla	Blas Myles PHM515 CS3 11-21-2017 - mylesbla.mp4
# V:\Students\cabright	Brighton Christopher PHM515 CS3 11-21-2017 - cabright.mp4
# V:\Students\mbutler6	Butler Matthew PHM515 CS3 11-21-2017 - mbutler6.mp4
# V:\Students\mbutler5	Butler McKenna PHM515 CS3 11-21-2017 - mbutler5.mp4
# V:\Students\dcai2	Cai Dennis PHM515 CS3 11-21-2017 - dcai2.mp4
# V:\Students\giselaca	Canales Gisela PHM515 CS3 11-21-2017 - giselaca.mp4
# V:\Students\ncashman	Cashman Nicholas PHM515 CS3 11-21-2017 - ncashman.mp4
# V:\Students\garrycha	Chan Garry PHM515 CS3 11-21-2017 - garrycha.mp4
# V:\Students\jchen222	Chen Jack PHM515 CS3 11-21-2017 - jchen222.mp4
# ...

# %%
os.chdir("V:\Students")

# %%
os.listdir()
# Out:
# ['aabdelra',
#  'aagawron',
#  'aahmad3',
#  'aaltman',
#  'aarontay',
#  'abbyforn',
#  'abtoscan',
#  'acao',
#  'achan38',
#  'achan39',
#  'acmocny',
#  'aconenna',
#  'acoughli',
#  'adamcart',
#  'adampark',
#  'adamsaly',
#  'adamtong',
#  'adcharle',
#  'adegelor',
#  'adesayoa',
#  'aebinkle',
#  'aeoddi',
#  'agao',
#  'agnarain',
#  'ah24',
#  'ahmedsae',
#  'ajhuang',
#  'ajw28',
#  'ajzach',
#  'akeller2',
#  'akosteck',
#  'akosuabe',
#  'aldenmoy',
#  'alecroma',
#  'alexaort',
#  'alexprin',
#  'alexyu',
#  'alfredye',
#  'aliang3',
#  'alicezhe',
#  'aliscrim',
#  'alisonmi',
#  'allenv',
#  'almogul',
#  'alraditi',
#  'alschepa',
#  'altorres',
#  'alyssaca',
#  'alyssadr',
#  'alyssamo',
#  'alyssatu',
#  'am343',
#  'amak',
#  'amak2',
#  'amandaye',
#  'amarkus',
#  'amgalbo2',
#  'amnobel',
#  'amsciort',
#  'amwatter',
#  'amydrzew',
#  'amyshave',
#  'amysuen',
#  'amywnuk',
#  'andli430',
#  'andrewne',
#  'andrewso',
#  'andreypo',
#  'andylam',
# ...

# %%
shutil.copy(src=i,dst="V:\\Students\\"+str(i[i.index(" - ")+3:-4]))
# Out:
# 'V:\\Students\\shuqingz\\Zhong Shu Qing PHM515 CS1 10-03-2017 - shuqingz.asf'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dpaul7\\VideoArchives'

# %%
for i in os.listdir():
    if(" - " in i):
        os.remove(i)
