# %%
import os
import pandas as pd

# %%
os.chdir("C:\\Users\\dpaul7\\VideoArchives")

# %%
os.listdir()
# Out:
# ['250A.asf',
#  '250B.asf',
#  '250C.asf',
#  '250D.asf',
#  '250E.asf',
#  '250F.asf',
#  '250G.asf',
#  '250H.asf',
#  '250J.asf',
#  '250K.asf',
#  '250L.asf',
#  '250M.asf',
#  'PHM 516 - 02-28-2018 - Room 250A - denisvan.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - jinchany.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - jxu38.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - mbutler6.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - mcquaids.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - neerajjo.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - nliang3.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - rajveerd.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - vavlasev.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - xinyingz.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - yutingti.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - andytsan.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - chichuen.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - cshum.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - epudim.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - giselaca.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - hmlevent.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - maggiekr.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - mylesbla.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - rmmesina.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - ryantobe.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - yonghuaq.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - agao.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - amwatter.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - cbzemane.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - ejaffe.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - izumiham.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - jchen222.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - jestanto.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - nbhasin2.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - roksolan.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - samourra.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - zhileich.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - chiwaifa.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - dhvanish.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - garrycha.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - habiburr.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - jamesvog.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - jintaoli.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - jwang44.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - lenakuff.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - llin52.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - ngannguy.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - yanivlev.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - awsherma.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - bklee4.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - chunghon.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - jpmeyer.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - kmgentz.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - mdanilov.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - mfrankla.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - quocvana.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - sarastor.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - willanes.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - alexyu.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - autumnpu.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - brennage.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - chhetens.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - hlgarr.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - jrvanamb.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - lanchen.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - lydiadei.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - ncashman.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - shibeili.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - tmlatval.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - am343.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - dvfitzgi.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - fionawu.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - kamrunka.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - katywang.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - kd67.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - kongyuch.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - rsinger.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - smmayer2.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - susandoa.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - vgetman.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - alicezhe.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - ceciliaf.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - csingh5.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - empatt.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - jdnowak.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - lauriepl.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - zakiyarh.mp4']

# %%
ren=pd.read_excel("rename.xlsx")

# %%
ren
# Out:
#                                             old  \
# 0          Augostini Anna PHM515 CS1 10-03-2017
# 1         Bhasin Nicholas PHM515 CS1 10-03-2017
# 2            Bienko Kevin PHM515 CS1 10-03-2017
# 3              Blas Myles PHM515 CS1 10-03-2017
# 4          Butler Matthew PHM515 CS1 10-03-2017
# 5          Butler McKenna PHM515 CS1 10-03-2017
# 6              Cai Dennis PHM515 CS1 10-03-2017
# 7        Cashman Nicholas PHM515 CS1 10-03-2017
# 8              Chan Garry PHM515 CS1 10-03-2017
# 9               Chen Jack PHM515 CS1 10-03-2017
# 10               Chen Lan PHM515 CS1 10-03-2017
# 11            Chen Zhilei PHM515 CS1 10-03-2017
# 12             Coiro Mark PHM515 CS1 10-03-2017
# 13        Danilov Michael PHM515 CS1 10-03-2017
# 14         Deinhart Lydia PHM515 CS1 10-03-2017
# 15      Dhaliwall Rajveer PHM515 CS1 10-03-2017
# 16             Fan Chiwai PHM515 CS1 10-03-2017
# 17      Fitzgibbon Dennis PHM515 CS1 10-03-2017
# 18         Fratus Cecilia PHM515 CS1 10-03-2017
# 19            Gao Anthony PHM515 CS1 10-03-2017
# 20           Gelen Brenna PHM515 CS1 10-03-2017
# 21          Gentz Kathryn PHM515 CS1 10-03-2017
# 22          Gilbert Jared PHM515 CS1 10-03-2017
# 23          Grimm Caitlin PHM515 CS1 10-03-2017
# 24       Halligan Kaitlin PHM515 CS1 10-03-2017
# 25          Jaffe Emanuel PHM515 CS1 10-03-2017
# 26       Kalappura Wesley PHM515 CS1 10-03-2017
# 27        Krikheli Maggie PHM515 CS1 10-03-2017
# 28    Kuffor-Afriyie Lena PHM515 CS1 10-03-2017
# 29          Leong Richard PHM515 CS1 10-03-2017
# ..                                          ...
# 36            Mayer Shawn PHM515 CS1 10-03-2017
# 37          Mesina Rachel PHM515 CS1 10-03-2017
# 38         Michalski Evan PHM515 CS1 10-03-2017
# 39         Murray Frances PHM515 CS1 10-03-2017
# 40            Nguyen Ngan PHM515 CS1 10-03-2017
# 41           Ortega Alexa PHM515 CS1 10-03-2017
# 42           Pang Charles PHM515 CS1 10-03-2017
# 43          Patrick Casey PHM515 CS1 10-03-2017
# 44              Pham Quoc PHM515 CS1 10-03-2017
# 45       Plewinski Laurie PHM515 CS1 10-03-2017
# 46        Polukhin Andrey PHM515 CS1 10-03-2017
# 47          Punter Autumn PHM515 CS1 10-03-2017
# 48            Qin Yonghua PHM515 CS1 10-03-2017
# 49           Rahman Farin PHM515 CS1 10-03-2017
# 50          Rhodie Zakiya PHM515 CS1 10-03-2017
# 51         Rusch Caroline PHM515 CS1 10-03-2017
# 52  Saint-Hilaire Willane PHM515 CS1 10-03-2017
# 53              Shao Mike PHM515 CS1 10-03-2017
# 54      Sherman Alexander PHM515 CS1 10-03-2017
# 55      Singh Christopher PHM515 CS1 10-03-2017
# 56       Stanton Jennifer PHM515 CS1 10-03-2017
# 57          Thompson Mary PHM515 CS1 10-03-2017
# 58           Vanini Denis PHM515 CS1 10-03-2017
# 59             Voyer Kira PHM515 CS1 10-03-2017
# 60           Wat Sang Kit PHM515 CS1 10-03-2017
# 61          Yan QiangQian PHM515 CS1 10-03-2017
# 62           Yu Chung Hon PHM515 CS1 10-03-2017
# 63           Zak Benjamin PHM515 CS1 10-03-2017
# 64         Zheng Xin Ying PHM515 CS1 10-03-2017
# 65           Zheng Xinyue PHM515 CS1 10-03-2017
#
#                                                   new
# 0     Augostini Anna PHM515 CS1 10-03-2017 - annaaugo
# 1    Bhasin Nicholas PHM515 CS1 10-03-2017 - nbhasin2
# 2       Bienko Kevin PHM515 CS1 10-03-2017 - kevinbie
# 3         Blas Myles PHM515 CS1 10-03-2017 - mylesbla
# 4     Butler Matthew PHM515 CS1 10-03-2017 - mbutler6
# 5     Butler McKenna PHM515 CS1 10-03-2017 - mbutler5
# 6            Cai Dennis PHM515 CS1 10-03-2017 - dcai2
# 7   Cashman Nicholas PHM515 CS1 10-03-2017 - ncashman
# 8         Chan Garry PHM515 CS1 10-03-2017 - garrycha
# 9          Chen Jack PHM515 CS1 10-03-2017 - jchen222
# 10           Chen Lan PHM515 CS1 10-03-2017 - lanchen
# 11       Chen Zhilei PHM515 CS1 10-03-2017 - zhileich
# 12        Coiro Marc PHM515 CS1 10-03-2017 - marccoir
# 13   Danilov Michael PHM515 CS1 10-03-2017 - mdanilov
# 14    Deinhart Lydia PHM515 CS1 10-03-2017 - lydiadei
# 15  Dhaliwall Rajveer PHM515 CS1 10-03-2017 - rajv...
# 16        Fan Chiwai PHM515 CS1 10-03-2017 - chiwaifa
# 17  Fitzgibbon Dennis PHM515 CS1 10-03-2017 - dvfi...
# 18    Fratus Cecilia PHM515 CS1 10-03-2017 - ceciliaf
# 19           Gao Anthony PHM515 CS1 10-03-2017 - agao
# 20      Gelen Brenna PHM515 CS1 10-03-2017 - brennage
# 21      Gentz Kathryn PHM515 CS1 10-03-2017 - kmgentz
# 22     Gilbert Jared PHM515 CS1 10-03-2017 - jaredgil
# 23      Grimm Caitlin PHM515 CS1 10-03-2017 - cngrimm
# 24  Halligan Kaitlin PHM515 CS1 10-03-2017 - kjhallig
# 25       Jaffe Emanuel PHM515 CS1 10-03-2017 - ejaffe
# 26  Kalappura Wesley PHM515 CS1 10-03-2017 - wesleyka
# 27   Krikheli Maggie PHM515 CS1 10-03-2017 - maggiekr
# 28  Kuffuor‐Afriyie Lena PHM515 CS1 10-03-2017 - l...
# 29       Leong Richard PHM515 CS1 10-03-2017 - rleong
# ..                                                ...
# 36       Mayer Shawn PHM515 CS1 10-03-2017 - smmayer2
# 37     Mesina Rachel PHM515 CS1 10-03-2017 - rmmesina
# 38    Michalski Evan PHM515 CS1 10-03-2017 - evanmich
# 39    Murray Frances PHM515 CS1 10-03-2017 - francesm
# 40       Nguyen Ngan PHM515 CS1 10-03-2017 - ngannguy
# 41      Ortega Alexa PHM515 CS1 10-03-2017 - alexaort
# 42        Pang Charles PHM515 CS1 10-03-2017 - cpang3
# 43     Patrick Casey PHM515 CS1 10-03-2017 - caseypat
# 44         Pham Quoc PHM515 CS1 10-03-2017 - quocvana
# 45  Plewinski Laurie PHM515 CS1 10-03-2017 - lauriepl
# 46   Polukhin Andrey PHM515 CS1 10-03-2017 - andreypo
# 47     Punter Autumn PHM515 CS1 10-03-2017 - autumnpu
# 48       Qin Yonghua PHM515 CS1 10-03-2017 - yonghuaq
# 49      Rahman Farin PHM515 CS1 10-03-2017 - rifatrah
# 50     Rhodie Zakiya PHM515 CS1 10-03-2017 - zakiyarh
# 51     Rusch Caroline PHM515 CS1 10-03-2017 - cerusch
# 52  Saint‐Hilaire Willane PHM515 CS1 10-03-2017 - ...
# 53         Shao Mike PHM515 CS1 10-03-2017 - mikeshao
# 54  Sherman Alexander PHM515 CS1 10-03-2017 - awsh...
# 55  Singh Christopher PHM515 CS1 10-03-2017 - csingh5
# 56  Stanton Jennifer PHM515 CS1 10-03-2017 - jestanto
# 57         Thompson Mary PHM515 CS1 10-03-2017 - mat3
# 58      Vanini Denis PHM515 CS1 10-03-2017 - denisvan
# 59        Voyer Kira PHM515 CS1 10-03-2017 - kiravoye
# 60      Wat Sang Kit PHM515 CS1 10-03-2017 - sangkitw
# 61         Yan QianQian PHM515 CS1 10-03-2017 - qyan2
# 62      Yu Chung Hon PHM515 CS1 10-03-2017 - chunghon
# 63         Zak Benjamin PHM515 CS1 10-03-2017 - bazak
# 64    Zheng Xin Ying PHM515 CS1 10-03-2017 - xinyingz
# 65       Zheng Xinyue PHM515 CS1 10-03-2017 - xzheng9
#
# [66 rows x 2 columns]

# %%
ren['old'].iloc[65]
# Out:
# 'Zheng Xinyue PHM515 CS1 10-03-2017'

# %%
range(len(os.listdir()))
# Out:
# range(0, 9)

# %%
os.listdir()[60][:-4]==ren['old'].iloc[60]
# Out:
# True

# %%
for i in range(len(os.listdir())):
    if(os.listdir()[i][:-4]==ren['old'].iloc[i]):
        os.rename(os.listdir()[i],ren['new'].iloc[i]+".asf")

# %%
a='PHM 516 - 11-07-2017 - Room 250K - warrenba.mp4'

# %%
'516' in a
# Out:
# True

# %%
os.chdir("..\\PHM 516 - 11-07-2017")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dpaul7\\PHM 516 - 11-07-2017'

# %%
for i in os.listdir():
    if('516' in i):
        os.rename(i,i.replace('516','615'))

# %%
a.replace('516','615')
# Out:
# 'PHM 615 - 11-07-2017 - Room 250K - warrenba.mp4'

# %%
os.listdir()
# Out:
# ['250A.asf',
#  '250B.asf',
#  '250C.asf',
#  '250D.asf',
#  '250E.asf',
#  '250F.asf',
#  '250G.asf',
#  '250H.asf',
#  '250J.asf',
#  '250K.asf',
#  '250L.asf',
#  '250M.asf',
#  'PHM 516 - 02-28-2018 - Room 250A - denisvan.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - jinchany.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - jxu38.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - mbutler6.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - mcquaids.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - neerajjo.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - nliang3.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - rajveerd.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - vavlasev.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - xinyingz.mp4',
#  'PHM 516 - 02-28-2018 - Room 250A - yutingti.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - andytsan.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - chichuen.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - cshum.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - epudim.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - giselaca.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - hmlevent.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - maggiekr.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - mylesbla.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - rmmesina.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - ryantobe.mp4',
#  'PHM 516 - 02-28-2018 - Room 250B - yonghuaq.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - agao.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - amwatter.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - cbzemane.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - ejaffe.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - izumiham.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - jchen222.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - jestanto.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - nbhasin2.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - roksolan.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - samourra.mp4',
#  'PHM 516 - 02-28-2018 - Room 250C - zhileich.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - chiwaifa.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - dhvanish.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - garrycha.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - habiburr.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - jamesvog.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - jintaoli.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - jwang44.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - lenakuff.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - llin52.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - ngannguy.mp4',
#  'PHM 516 - 02-28-2018 - Room 250D - yanivlev.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - awsherma.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - bklee4.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - chunghon.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - jpmeyer.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - kmgentz.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - mdanilov.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - mfrankla.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - quocvana.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - sarastor.mp4',
#  'PHM 516 - 02-28-2018 - Room 250E - willanes.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - alexyu.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - autumnpu.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - brennage.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - chhetens.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - hlgarr.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - jrvanamb.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - lanchen.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - lydiadei.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - ncashman.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - shibeili.mp4',
#  'PHM 516 - 02-28-2018 - Room 250F - tmlatval.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - am343.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - dvfitzgi.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - fionawu.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - kamrunka.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - katywang.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - kd67.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - kongyuch.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - rsinger.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - smmayer2.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - susandoa.mp4',
#  'PHM 516 - 02-28-2018 - Room 250G - vgetman.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - alicezhe.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - btsang.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - ceciliaf.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - csingh5.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - empatt.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - jdnowak.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - lauriepl.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - njfraass.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - rleong.mp4',
#  'PHM 516 - 02-28-2018 - Room 250H - zakiyarh.mp4']

# %%
import os
import shutil

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dpaul7\\VideoArchives'

# %%
os.chdir("C:\\Users\\dpaul7\\VideoArchives")

# %%
len(os.listdir())
# Out:
# 11

# %%
for i in os.listdir():
    if(".mp4" in i):
        print("V:\\Students\\"+str(i[i.index("250")+7:-4])+"\t"+i)
        shutil.copy(src=i,dst="V:\\Students\\"+str(i[i.index("250")+7:-4]))
#         os.rename(i,i.replace("_%T1",""))
# Out:
# V:\Students\alexaort	PHM 516 - 02-28-2018 - Room 250J - alexaort.mp4
# V:\Students\bazak	PHM 516 - 02-28-2018 - Room 250J - bazak.mp4
# V:\Students\cabright	PHM 516 - 02-28-2018 - Room 250J - cabright.mp4
# V:\Students\cerusch	PHM 516 - 02-28-2018 - Room 250J - cerusch.mp4
# V:\Students\evanmich	PHM 516 - 02-28-2018 - Room 250J - evanmich.mp4
# V:\Students\jiaweihu	PHM 516 - 02-28-2018 - Room 250J - jiaweihu.mp4
# V:\Students\jsalavat	PHM 516 - 02-28-2018 - Room 250J - jsalavat.mp4
# V:\Students\kjhallig	PHM 516 - 02-28-2018 - Room 250J - kjhallig.mp4
# V:\Students\marccoir	PHM 516 - 02-28-2018 - Room 250J - marccoir.mp4
# V:\Students\shuqingz	PHM 516 - 02-28-2018 - Room 250J - shuqingz.mp4

# %%
os.chdir("V:\Students")

# %%
os.listdir()
# Out:
# ['aabdelra',
#  'aagawron',
#  'aahmad3',
#  'aaltman',
#  'aarontay',
#  'abbyforn',
#  'abtoscan',
#  'acao',
#  'achan38',
#  'achan39',
#  'acmocny',
#  'aconenna',
#  'acoughli',
#  'adamcart',
#  'adampark',
#  'adamsaly',
#  'adamtong',
#  'adcharle',
#  'adegelor',
#  'adesayoa',
#  'aebinkle',
#  'aeoddi',
#  'agao',
#  'agnarain',
#  'ah24',
#  'ahmedsae',
#  'ajhuang',
#  'ajw28',
#  'ajzach',
#  'akeller2',
#  'akosteck',
#  'akosuabe',
#  'aldenmoy',
#  'alecroma',
#  'alexaort',
#  'alexprin',
#  'alexyu',
#  'alfredye',
#  'aliang3',
#  'alicezhe',
#  'aliscrim',
#  'alisonmi',
#  'allenv',
#  'almogul',
#  'alraditi',
#  'alschepa',
#  'altorres',
#  'alyssaca',
#  'alyssadr',
#  'alyssamo',
#  'alyssatu',
#  'am343',
#  'amak',
#  'amak2',
#  'amandaye',
#  'amarkus',
#  'amgalbo2',
#  'amnobel',
#  'amsciort',
#  'amwatter',
#  'amydrzew',
#  'amyshave',
#  'amysuen',
#  'amywnuk',
#  'andli430',
#  'andrewne',
#  'andrewso',
#  'andreypo',
#  'andylam',
#  'andytsan',
#  'anessian',
#  'anguyen9',
#  'anilmela',
#  'ankitsen',
#  'annaaugo',
#  'annaesch',
#  'annalian',
#  'annamori',
#  'annaslav',
#  'annichen',
#  'anpieprz',
#  'ap68',
#  'arieneta',
#  'arivera7',
#  'arsmith6',
#  'atreidy',
#  'atse',
#  'atuldila',
#  'autumnpu',
#  'averybal',
#  'avolovik',
#  'awalker5',
#  'awfyles',
#  'awsherma',
#  'ayajporo',
#  'ayliang',
#  'babanks',
#  'baboland',
#  'barneyga',
#  'bawatten',
#  'bayliesl',
#  'bazak',
#  'bbbratek',
#  'bbegnoch',
#  'bcwong2',
#  'bdbrowne',
#  'benli',
#  'bennyvuo',
#  'benrobin',
#  'bettyvu',
#  'bhumipat',
#  'bingqing',
#  'bisiaiye',
#  'bjcrimmi',
#  'bjmcmanu',
#  'bjwolski',
#  'bklee4',
#  'blai',
#  'blen',
#  'bls9',
#  'blslocum',
#  'blwoods',
#  'bmbailey',
#  'bmlutley',
#  'bmr4',
#  'bna4',
#  'boqiangw',
#  'bozhou',
#  'bpbaur',
#  'brendaol',
#  'brendayu',
#  'brennaga',
#  'brennage',
#  'brianasz',
#  'brianbow',
#  'briansul',
#  'brianvoo',
#  'brittney',
#  'bryanfel',
#  'bryanmog',
#  'bryanqui',
#  'brynnacr',
#  'bsbasile',
#  'bskemati',
#  'bszurek',
#  'btsang',
#  'byunghee',
#  'cabernha',
#  'cabright',
#  'cadefede',
#  'cagawron',
#  'caitlinf',
#  'caitlynh',
#  'canaphyl',
#  'caramcgu',
#  'carlypoc',
#  'carmenle',
#  'carolleo',
#  'caseypat',
#  'caskript',
#  'caydensq',
#  'cbarbour',
#  'cbbarron',
#  'cbchehov',
#  'cbzemane',
#  'ccchin',
#  'cchan27',
#  'ccpiccio',
#  'cdiep',
#  'cdv3',
#  'cdvu',
#  'ceciliaf',
#  'cemeyer5',
#  'cerusch',
#  'cghinton',
#  'charlesl',
#  'chhetens',
#  'chhimesh',
#  'chichuen',
#  'chihualu',
#  'chiwaifa',
#  'christan',
#  'christyc',
#  'chungche',
#  'chunghon',
#  'ciaratro',
#  'cierapat',
#  'cindywu',
#  'cjharvey',
#  'cjones7',
#  'cjsmith8',
#  'ck66',
#  'clareton',
#  'cldrake2',
#  'clwarsaw',
#  'cmbanker',
#  'cmcardin',
#  'cmcieri',
#  'cmgbeoji',
#  'cmhoar',
#  'cmkowalc',
#  'cmm67',
#  'cmmamone',
#  'cmmckinn',
#  'cmnicoli',
#  'cmryan5',
#  'cmv6',
#  'cngrimm',
#  'codyrach',
#  'codyzhan',
#  'colinhai',
#  'colleeng',
#  'collincl',
#  'coreywel',
#  'corycole',
#  'cpang3',
#  'cplaforg',
#  'cptanski',
#  'craigsau',
#  'crc26',
#  'cshum',
#  'csingh5',
#  'csliu',
#  'cszkutak',
#  'cuilingz',
#  'cwang22',
#  'cwsmith5',
#  'cyu3',
#  'danamunn',
#  'danemunz',
#  'danjinch',
#  'danyanyu',
#  'davidess',
#  'davidhuo',
#  'davidpeg',
#  'davidszy',
#  'dbsmith',
#  'dcai2',
#  'ddavide',
#  'deannani',
#  'deborahw',
#  'denisvan',
#  'dennishu',
#  'deonedio',
#  'devoncof',
#  'dhiralpa',
#  'dhvanish',
#  'dianlin',
#  'divyaobe',
#  'djladd',
#  'djvaris',
#  'dkalpaki',
#  'dlcao',
#  'dlsobczy',
#  'dlzhang',
#  'dmhanzli',
#  'dmitriys',
#  'dmkieck',
#  'dngirgis',
#  'donaldsi',
#  'doohyunh',
#  'dustinan',
#  'dustinne',
#  'dvfitzgi',
#  'dwen2',
#  'eacofie',
#  'ealakota',
#  'ealiufu',
#  'ebnerafi',
#  'ebnesafi',
#  'echa2',
#  'ejaffe',
#  'ejeansim',
#  'ekim28',
#  'elee27',
#  'elfield',
#  'elisator',
#  'elissach',
#  'elvisvel',
#  'emdahl',
#  'emhart',
#  'emileeya',
#  'emiliebu',
#  'emilyhul',
#  'emilynir',
#  'emilythu',
#  'emilyvol',
#  'emmagarg',
#  'empatt',
#  'epudim',
#  'ericaho',
#  'ericajet',
#  'ericaorl',
#  'ericlenh',
#  'ericnova',
#  'ericscot',
#  'erikheft',
#  'erindavi',
#  'erinmcew',
#  'erinwatt',
#  'eshao',
#  'esramust',
#  'estheres',
#  'estheryi',
#  'eunbyeol',
#  'euniceag',
#  'evanmich',
#  'ewang23',
#  'fadesina',
#  'faisalmi',
#  'faizariz',
#  'falcone6',
#  'fangchih',
#  'fankaizh',
#  'farhadfo',
#  'fathimat',
#  'faycreat',
#  'fchen7',
#  'fcsosnow',
#  'fdreed2',
#  'fedaasub',
#  'fhyung',
#  'fionawu',
#  'flin7',
#  'francesm',
#  'frazier8',
#  'frencina',
#  'gaochong',
#  'garrycha',
#  'gcozzi',
#  'gdkrawie',
#  'gdmartin',
#  'georgiad',
#  'geoswald',
#  'giannaog',
#  'gigiyam',
#  'ginasute',
#  'giselaca',
#  'gjcastel',
#  'gkoopman',
#  'gpstatt',
#  'gunjansh',
#  'gurjotsa',
#  'gvfiorel',
#  'gwbrown',
#  'gzhang',
#  'habiburr',
#  'haihuiwu',
#  'haleysch',
#  'handreww',
#  'hanhnguy',
#  'hannahbi',
#  'haominch',
#  'hauyenph',
#  'hayoungr',
#  'hbyun',
#  'heatherd',
#  'heliajaz',
#  'hempling',
#  'henachou',
#  'hengli',
#  'hengxinl',
#  'henrywil',
#  'hestaple',
#  'hkim49',
#  'hl85',
#  'hlgarr',
#  'hlgrove',
#  'hliang7',
#  'hliu28',
#  'hlpasley',
#  'hmlevent',
#  'hoyoungl',
#  'hpatel8',
#  'hrnorton',
#  'hubertco',
#  'huihongl',
#  'husainah',
#  'hwlee2',
#  'hyejikim',
#  'hyeonsuk',
#  'hyunghoo',
#  'hyunminp',
#  'ianbader',
#  'idmartin',
#  'ifeologb',
#  'iffatsha',
#  'ilanacyp',
#  'ilee4',
#  'ishitame',
#  'izumiham',
#  'jaaguila',
#  'jaclynko',
#  'jacobger',
#  'jacobrea',
#  'jaimiero',
#  'jakekinl',
#  'jakilins',
#  'jakubsno',
#  'jamespuf',
#  'jamesvog',
#  'jamiegae',
#  'jamielig',
#  'janetche',
#  'janetpoo',
#  'jaredcra',
#  'jaredgil',
#  'jaredmoo',
#  'jaryndak',
#  'jasantin',
#  'jasminen',
#  'jasondey',
#  'jasonvot',
#  'jb272',
#  'jbui',
#  'jcbader',
#  'jchen222',
#  'jckahi',
#  'jdeiley',
#  'jdnowak',
#  'jds48',
#  'jdwiafe',
#  'jeffreyo',
#  'jekowals',
#  'jennacov',
#  'jennahur',
#  'jennaose',
#  'jennycha',
#  'jennyli',
#  'jennyqiu',
#  'jerricat',
#  'jestanto',
#  'jggreger',
#  'jglamarc',
#  'jgoo3',
#  'jgpalumb',
#  'jianquan',
#  'jiaweihu',
#  'jibaron',
#  'jiegu',
#  'jinchany',
#  'jinghe',
#  'jingluhu',
#  'jingyint',
#  'jinheepa',
#  'jintaoli',
#  'jjhan3',
#  'jjin3',
#  'jjjager',
#  'jjlennon',
#  'jjz3',
#  'jko3',
#  'jkuroski',
#  'jkwok',
#  'jlashbau',
#  'jlenhard',
#  'jlhiller',
#  'jlin49',
#  'jlklinge',
#  'jlmeyers',
#  'jlraffer',
#  'jmbernar',
#  'jmeaney',
#  'jmmason',
#  'jmmilews',
#  'jmurray2',
#  'jn39',
#  'jncostel',
#  'jng39',
#  'jnisaac',
#  'jnmiccer',
#  'joanneta',
#  'johnarle',
#  'johndiep',
#  'johnfras',
#  'johnmyun',
#  'johnnywa',
#  'johntang',
#  'johntren',
#  'johnyuan',
#  'jokeitab',
#  'jonjjager',
#  'joonji',
#  'joonseoy',
#  'josephsp',
#  'joshschr',
#  'jostroff',
#  'jovinpan',
#  'joysnyde',
#  'jpando',
#  'jpawlak4',
#  'jpmeyer',
#  'jpulliam',
#  'jr262',
#  'jrroulle',
#  'jrvanamb',
#  'js276',
#  'jsalavat',
#  'jsgall2',
#  'jshossai',
#  'jsitu',
#  'jsmasten',
#  'jswidere',
#  'jtbeyer',
#  'judylam',
#  'juerongp',
#  'juliahah',
#  'julialee',
#  'juliapow',
#  'juliawal',
#  'juliegra',
#  'julieobe',
#  'junminli',
#  'justinat',
#  'justinbi',
#  'justinos',
#  'justinwa',
#  'jwang44',
#  'jxie4',
#  'jxsulesk',
#  'jxu38',
#  'jychoi5',
#  'jyou3',
#  'jzhang43',
#  'kabbott2',
#  'kachmiel',
#  'kahowong',
#  'kahtanal',
#  'kaitlynv',
#  'kaitlynw',
#  'kalunhun',
#  'kamrunka',
#  'karenlou',
#  'kasunder',
#  'kateylyn',
#  'katrinne',
#  'katywang',
#  'kcdaiya',
#  'kcgomes',
#  'kchen34',
#  'kcnghiem',
#  'kd67',
#  'kefodero',
#  'kegrogan',
#  'keithdol',
#  'kejtitos',
#  'kekriege',
#  'kellyros',
#  'kelseyvi',
#  'kemarkie',
#  'kendrani',
#  'kentlee',
#  'kerryarc',
#  'kescott2',
#  'kevinbie',
#  'kevinchi',
#  'kevindug',
#  'kevinkaw',
#  'kevinlav',
#  'kevinmcd',
#  'kevinsul',
#  'kevinsze',
#  'keziatav',
#  'kgancasz',
#  'khadeeja',
#  'khalifos',
#  'khart2',
#  'khasnat',
#  'khyatibe',
#  'kiravoye',
#  'kjacobse',
#  'kjboakye',
#  'kjhallig',
#  'kkchan',
#  'klangdon',
#  'klau3',
#  'klee22',
#  'klin6',
#  'kltrieu',
#  'km252',
#  'kmaudley',
#  'kmaxwell',
#  'kmdixon3',
#  'kmgentz',
#  'kmgreene',
#  'kmlandol',
#  'kmm69',
#  'kmrusso2',
#  'kongyuch',
#  'koryzele',
#  'kprajapa',
#  'kristila',
#  'krm27',
#  'krmccadd',
#  'ksjerz',
#  'kushgrov',
#  'kwadwoba',
#  'kwannokl',
#  'kwprouty',
#  'kyleegro',
#  'kylegeor',
#  'kylepola',
#  'kyleuebl',
#  'kyungsoo',
#  'kzarudna',
#  'lanchen',
#  'lanhsili',
#  'laurabie',
#  'lauriepl',
#  'lchang22',
#  'lchen46',
#  'ldingman',
#  'leahandr',
#  'leaperry',
#  'lenakuff',
#  'leonowus',
#  'leslieau',
#  'liangzhu',
#  'linawu',
#  'lindseyf',
#  'linfengg',
#  'linxin',
#  'lisayama',
#  'liujingl',
#  'lknguyen',
#  'lks4',
#  'lleung2',
#  'lli57',
#  'llin52',
#  'lmfovel',
#  'lmnigrel',
#  'lorenpav',
#  'louismar',
#  'lpwratte',
#  'lrbruss',
#  'lucasgre',
#  'lukasbri',
#  'lukehoff',
#  'lydiadei',
#  'madalynr',
#  'madeiraa',
#  'madeline',
#  'maggiehu',
#  'maggiekr',
#  'mahsasal',
#  'maluo',
#  'maluttin',
#  'mamietal',
#  'mamiklic',
#  'manamiyo',
#  'manavwah',
#  'mantingc',
#  'marccoir',
#  'marcelen',
#  'mariahig',
#  'mariajan',
#  'mariamin',
#  'marielyc',
#  'mariobec',
#  'marklevy',
#  'marombol',
#  'maryhejn',
#  'masoncha',
#  'mat3',
#  'matiasen',
#  'mayahols',
#  'mayuribe',
#  'mburns2',
#  'mbutler5',
#  'mbutler6',
#  'mcp25',
#  'mcquaids',
#  'mcsafir',
#  'mdanilov',
#  'mdaustin',
#  'mdbear',
#  'meamsler',
#  'megangee',
#  'meganoco',
#  'meganske',
#  'meghanli',
#  'meghanlo',
#  'meizhiho',
#  'melanieh',
#  'melektur',
#  'melindan',
#  'merice',
#  'merinpan',
#  'mfrankla',
#  'mfrinere',
#  'mfung2',
#  'mhismail',
#  'miamagli',
#  'michaelr',
#  'mikeshao',
#  'minjeong',
#  'mjb52',
#  'mkmcgowa',
#  'mldo',
#  'mlgraham',
#  'mllandgr',
#  'mmohamma',
#  'mmporemb',
#  'mn65',
#  'mnschlom',
#  'mp223',
#  'mpgarvin',
#  'mpnguyen',
#  'mrbelair',
#  'mrc35',
#  'mrdhanra',
#  'mrguszko',
#  'mridulsi',
#  'mrlebrec',
#  'mrlee',
#  'mrlee3',
#  'mrlijews',
#  'mrmullin',
#  'mrwang',
#  'mshaintz',
#  'mshi3',
#  'msiu',
#  'msrozek',
#  'mtmauri',
#  'mtmunell',
#  'mwmalik',
#  'mylesbla',
#  'mylesbuh',
#  'nabilais',
#  'nabosso',
#  'nadiaman',
#  'nahidzam',
#  'naladzia',
#  'nantongl',
#  'naservat',
#  'nataliea',
#  'natalire',
#  'nazlisol',
#  'nbhasin2',
#  'ncashman',
#  'ncbecker',
#  'ndonofri',
#  'nealjohn',
#  'neerajjo',
#  'nem6',
#  'ngannguy',
#  'nhopwood',
#  'nicholec',
#  'nisazhao',
#  'nivetaje',
#  'njassif',
#  'njfilk',
#  'njfraass',
#  'nkdibudu',
#  'nkemakol',
#  'nliang3',
#  'nmk6',
#  'nmpetrel',
#  'nmsmith2',
#  'nmvannos',
#  'nmwilcox',
#  'norbertb',
#  'norbertf',
#  'npl',
#  'nppalisa',
#  'nrpatel3',
#  'nswinter',
#  'nwang6',
#  'nwilliam',
#  'nwrokjer',
#  'oddiogua',
#  'ogbonnay',
#  'omarmarz',
#  'oyaremko',
#  'parulmit',
#  'pashah',
#  'patrickg',
#  'paulaoru',
#  'pauleena',
#  'paulinac',
#  'paullupa',
#  'pdrossos',
#  'pem3',
#  'peterfen',
#  'peterpha',
#  'petertan',
#  'pfeng2',
#  'pgrose',
#  'philipye',
#  'pjm46',
#  'poyinhon',
#  'ps95',
#  'ptdo',
#  'puneetpr',
#  'pwjeu',
#  'qianwenh',
#  'qizheng',
#  'quocvana',
#  'quynhanh',
#  'qyan2',
#  'qyin',
#  'rabennet',
#  'rachaell',
#  'racheley',
#  'rahealbo',
#  'rajveerd',
#  'ramrit',
#  'raphewfa',
#  'rarotunn',
#  'rascott2',
#  'rbailey3',
#  'rbrodski',
#  'rcklosko',
#  'rctowne',
#  'rdillon2',
#  'reannspo',
#  'remeyer2',
#  'renaegoz',
#  'renatach',
#  'renchend',
#  'reneenov',
#  'resovoco',
#  'rickyloh',
#  'rifatrah',
#  'risikatb',
#  'rjh23',
#  'rjk22',
#  'rjmoore3',
#  'rjrovell',
#  'rkc4',
#  'rlaraujo',
#  'rleong',
#  'rmartin6',
#  'rmcardin',
#  'rmmesina',
#  'rmsze',
#  'rnelson2',
#  'robbsaun',
#  'roksolan',
#  'roshanra',
#  'rpatel6',
#  'rperacci',
#  'rplucare',
#  'rpparamb',
#  'rsinger',
#  'rtsmith2',
#  'ryanolau',
#  'ryanstja',
#  'ryantobe',
#  'sabrinaw',
#  'safavora',
#  'sakrafft',
#  'sammyyaf',
#  'samourra',
#  'samsadpa',
#  'samuelst',
#  'sangkitw',
#  'Saradelv',
#  'saraditu',
#  'sarahdas',
#  'sarahgro',
#  'sarahiss',
#  'sarahlyn',
#  'sarahree',
#  'sarahsch',
#  'sarahsck',
#  'sarahspi',
#  'sarastor',
#  'sarithsa',
#  'sayen',
#  'sblanza',
#  'sc235',
#  'scboyce',
#  'scfarr',
#  'schan22',
#  'schen27',
#  'schen32',
#  'scottbru',
#  'sejanuto',
#  'senbinzh',
#  'serakim',
#  'serenapa',
#  'serudolp',
#  'sfloarea',
#  'shahjabi',
#  'shahrier',
#  'shanitho',
#  'sharifso',
#  'shenazsh',
#  'shengzou',
#  'shibeili',
#  'shihanhu',
#  'shuqingz',
#  'sjmin',
#  'skaras',
#  'skim37',
#  'skim45',
#  'skylersw',
#  'sl248',
#  'slcarter',
#  'sliang25',
#  'sliang6',
#  'sm329',
#  'smmayer2',
#  'smrzygut',
#  'snehamon',
#  'sobczak',
#  'soheecha',
#  'solamana',
#  'somalist',
#  'somangch',
#  'sonyakim',
#  'soohyunk',
#  'sreekuru',
#  'srehrig',
#  'srf7',
#  'srwaugh',
#  'srwill',
#  'ssiu',
#  'sspawlak',
#  'stacieyi',
#  'stan6',
#  'stdmocho',
#  'sukyoung',
#  'sumayyah',
#  'susanche',
#  'susandoa',
#  'susanliu',
#  'suzychun',
#  'svpatel4',
#  'swiegand',
#  'swnemeth',
#  'syedsama',
#  'sylviaou',
#  'tannerme',
#  'taoranwa',
#  'tarakura',
#  'tashadha',
#  'tathiref',
#  'tatufuor',
#  'taviagar',
#  'taylorwh',
#  'tc56',
#  'tchen26',
#  'tcrawfor',
#  'thanhngu',
#  'themetri',
#  'thomas22',
#  'thomasst',
#  'thomasta',
#  'timothyz',
#  'tinalin',
#  'tjsisti',
#  'tkchan',
#  'tma26',
#  'tmfadale',
#  'tmlatval',
#  'tndevrie',
#  'tommyko',
#  'tonychan',
#  'tpan2',
#  'traciala',
#  'tracyhuy',
#  'travisro',
#  'travists',
#  'troyhoel',
#  'trucduon',
#  'tseringl',
#  'tspark',
#  'tszonlui',
#  'tylerbed',
#  'tylermul',
#  'tyou2',
#  'vadrynpi',
#  'vavlasev',
#  'vcooper',
#  'velee2',
#  'vfgoodri',
#  'vfung',
#  'vgetman',
#  'vgvanzo',
#  'vickitri',
#  'vincentd',
#  'vincentm',
#  'vinsonen',
#  'vishalpa',
#  'vnachar',
#  'vshin',
#  'vvohra',
#  'vwong5',
#  'vwronski',
#  'vzheng',
#  'waiinyu',
#  'waiyinle',
#  'walker45',
#  'warrenba',
#  'wcmichae',
#  'wdwendt',
#  'wesleyka',
#  'wesleyku',
#  ...]

# %%
shutil.copy(src=i,dst="V:\\Students\\"+str(i[i.index(" - ")+3:-4]))
# Out:
# 'V:\\Students\\shuqingz\\Zhong Shu Qing PHM515 CS1 10-03-2017 - shuqingz.asf'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dpaul7\\VideoArchives'

# %%
for i in os.listdir():
    if(" - " in i):
        os.remove(i)

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\dpaul7\\Jupyter'

# %%
os.chdir("C:\\Users\\dpaul7\\VideoArchives")

# %%
os.listdir()
# Out:
# ['PHM 616 - 03-27-2018 - Room 250A_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250A_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250B_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250B_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250C_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250C_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250D_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250D_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250E_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250E_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250F_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250F_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250G_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250G_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250H_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250H_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250J_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250J_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250K_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250K_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250L_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250L_%T1.asx',
#  'PHM 616 - 03-27-2018 - Room 250M_%T1.asf',
#  'PHM 616 - 03-27-2018 - Room 250M_%T1.asx']

# %%
for i in os.listdir():
    if(".asx" in i):
        os.remove(i)
#         print("V:\\Students\\"+str(i[i.index("250")+7:-4])+"\t"+i)

# %%
for i in os.listdir():
    if(".asf" in i):
         os.rename(i,i.replace('_%T1',''))
#         print("V:\\Students\\"+str(i[i.index("250")+7:-4])+"\t"+i)
